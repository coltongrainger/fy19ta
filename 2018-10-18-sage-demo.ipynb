# %% [markdown]
# ### HW 7.3.a

# %%
x,y = var('x,y')
d = plot_vector_field((y,-x), (x,-4,4), (y,-4,4))
f(x,y) = x^2 + y^2 - 10
p = implicit_plot(f, (-4,4),(-4,4))
d+p
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### HW 7.5

# %%
f(x,y) = x*y + e^y -e
h = 10
p = implicit_plot(f, (-h,h),(-h,h))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t2(x) = 1 + (-1/e)*x + (e^(-2))*x^2
taylor = plot(t2(x), (x,-h,h), color='red')
p+taylor
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### HW 8.1

# %%
f(x,y) = y*x^2 - arctan(x*y)
p = implicit_plot(f, (-1,1),(-1,1))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(arctan(x), (x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### HW 8.4

# %%
f(x) = arcsin(x^2 - 2*x)
plot(f, (x,-pi,pi))
# Out:
# verbose 0 (3761: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 110 points.
# verbose 0 (3761: plot.py, generate_plot_points) Last error message: ''
# Graphics object consisting of 1 graphics primitive
